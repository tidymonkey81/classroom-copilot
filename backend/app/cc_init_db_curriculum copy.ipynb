# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

import modules.logger_tool as logger
import os

os.environ['LOG_NAME'] = 'science'
os.environ['LOG_DIR'] = 'logs'
os.environ['LOG_LEVEL'] = 'INFO'

logging = logger.get_logger(os.environ['LOG_NAME'], log_level=os.environ['LOG_LEVEL'], log_path=os.environ['LOG_DIR'], log_file=os.environ['LOG_NAME'])

# %%
import modules.database.schemas.curriculum_neo as neo_curriculum
import modules.database.schemas.relationships.curricular_relationships as neo_relationships
import modules.database.tools.xl_planner_tools as planner
import modules.database.tools.neontology_tools as neon
import modules.database.tools.neo4j_driver_tools as driver_tools
import modules.database.tools.neo4j_session_tools as session_tools

import requests
import pandas as pd
from pydantic import ValidationError

# %%
db_name = 'science'

# %%
url = 'http://localhost:9500/database/admin/stop-database'
data = {'db_name': db_name}
response = requests.post(url, json=data)
logging.info(response.text)

url = 'http://localhost:9500/database/admin/drop-database'
data = {'db_name': db_name}
response = requests.post(url, json=data)
logging.info(response.text)
# Out:
# 2024-06-30 03:44:49,064 INFO      : 3522179693 > <module> >>> {"results":[{"columns":[],"data":[]}],"errors":[],"lastBookmarks":["FB:kcwQAAAAAAAAAAAAAAAAAAAAAckBBpA="]}
# 2024-06-30 03:44:51,130 INFO      : 3522179693 > <module> >>> {"results":[{"columns":[],"data":[]}],"errors":[],"lastBookmarks":["FB:kcwQAAAAAAAAAAAAAAAAAAAAAckBB5A="]}

# %%
url = 'http://localhost:9500/database/admin/create-database'
params = {'db_name': db_name}
response = requests.post(url, params=params)
logging.info(response.text)
# Out:
# 2024-06-30 03:44:53,266 INFO      : 2595822508 > <module> >>> {"results":[{"columns":[],"data":[]}],"errors":[],"lastBookmarks":["FB:kcwQAAAAAAAAAAAAAAAAAAAAAckBCJA="]}

# %%
driver = driver_tools.get_driver(database=db_name)
# Out:
# 2024-06-30 03:44:53,319 INFO      : neo4j_driver_tools > get_driver >>> Connection successful

# %%
neon.init_neo4j_connection()
# Out:
# 2024-06-30 03:44:53,460 INFO      : neontology_tools > init_neo4j_connection >>> Neontology connection initialized with host: 192.168.0.20, port: 7687, user: neo4j

# %%
excel_planner = planner.create_dataframes(os.getenv("EXCEL_PLANNER_FILE"))

topic_df = excel_planner['topiclookup_df']
lesson_df = excel_planner['lessonlookup_df']
statement_df = excel_planner['statementlookup_df']
keystagesyllabus_df = excel_planner['keystagesyllabuslookup_df']
yeargroupsyllabus_df = excel_planner['yeargroupsyllabuslookup_df']

# %%
default_topic_values = {
    'topic_assessment_type': 'Null',
    'topic_type': 'Null',
    'total_number_of_lessons_for_topic': '1',
    'topic_title': 'Null'
    }

default_topic_lesson_values = {
    'topic_lesson_title': 'Null',
    'topic_lesson_type': 'Null',
    'topic_lesson_length': '1',  # Ensure this is a string if the model expects a string
    'topic_lesson_suggested_activities': 'Null',
    'topic_lesson_skills_learned': 'Null',
    'topic_lesson_weblinks': 'Null',
}

default_learning_statement_values = {
    # Add default values for fields that might contain NaN
    'lesson_learning_statement': 'Null',
    'lesson_learning_statement_type': 'Student learning outcome'
}

# %%
# Dictionary to store nodes by their IDs and keep track of whether they have been created
node_library = {}
key_stage_nodes_created = {}  # Tracks whether a KeyStageNode has been created
year_group_nodes_created = {}  # Tracks YearGroupNodes creation by KeyStage

# Initialize previous node pointers
key_stage_prev_node = None
year_group_prev_node = {}

for index, ks_row in keystagesyllabus_df.sort_values('KeyStage').iterrows():
    key_stage = str(ks_row['KeyStage'])
    if key_stage not in key_stage_nodes_created:
        logging.info(f"Creating key stage node for {key_stage}")
        key_stage_node = neo_curriculum.KeyStageNode(
            key_stage_id=key_stage,
            key_stage_name=f"Key Stage {key_stage}"
        )
        neon.create_or_merge_neontology_node(key_stage_node, database=db_name, operation='merge')
        key_stage_nodes_created[key_stage] = key_stage_node
        node_library[key_stage] = key_stage_node  # Store in node_library for easy access
    else:
        logging.info(f"Key stage node for {key_stage} already exists")
        key_stage_node = key_stage_nodes_created[key_stage]

    key_stage_syllabus_node = neo_curriculum.KeyStageSyllabusNode(
        ks_syllabus_id=ks_row['ID'],
        ks_syllabus_name=ks_row['Title']
    )
    neon.create_or_merge_neontology_node(key_stage_syllabus_node, database=db_name, operation='merge')
    node_library[ks_row['ID']] = key_stage_syllabus_node  # Store in node_library

    neon.create_or_merge_neontology_relationship(
        neo_relationships.KeyStageIncludesKeyStageSyllabus(source=key_stage_node, target=key_stage_syllabus_node),
        database=db_name, operation='merge'
    )

    if key_stage_prev_node and key_stage_prev_node != key_stage_node:
        neon.create_or_merge_neontology_relationship(
            neo_relationships.KeyStageFollowsKeyStage(source=key_stage_prev_node, target=key_stage_node),
            database=db_name, operation='merge'
        )
    key_stage_prev_node = key_stage_node

    related_yeargroups = yeargroupsyllabus_df[yeargroupsyllabus_df['KeyStage'] == ks_row['KeyStage']].copy()
    related_yeargroups.loc[:, 'YearGroup'] = related_yeargroups['YearGroup'].astype(str)
    related_yeargroups = related_yeargroups.sort_values('YearGroup')

    for yg_index, yg_row in related_yeargroups.iterrows():
        year_group = yg_row['YearGroup']
        if year_group.isdigit() and (year_group) not in year_group_nodes_created:
            logging.info(f"Creating year group node for Year {year_group}")
            year_group_node = neo_curriculum.YearGroupNode(
                year_group_id=year_group,
                year_group_name=f"Year {year_group}"
            )
            neon.create_or_merge_neontology_node(year_group_node, database=db_name, operation='merge')
            year_group_nodes_created[(year_group)] = year_group_node
            node_library[year_group] = year_group_node  # Store in node_library
        elif year_group.isdigit():
            year_group_node = year_group_nodes_created[(year_group)]
        else:
            logging.warning(f"Skipping YearGroup {yg_row['YearGroup']} as it is not a digit.")
            continue

        year_group_syllabus_node = neo_curriculum.YearGroupSyllabusNode(
            yr_syllabus_id=yg_row['ID'],
            yr_syllabus_name=yg_row['Title']
        )
        neon.create_or_merge_neontology_node(year_group_syllabus_node, database=db_name, operation='merge')
        node_library[yg_row['ID']] = year_group_syllabus_node  # Store in node_library

        neon.create_or_merge_neontology_relationship(
            neo_relationships.YearGroupHasYearGroupSyllabus(source=year_group_node, target=year_group_syllabus_node),
            database=db_name, operation='merge'
        )
        neon.create_or_merge_neontology_relationship(
            neo_relationships.KeyStageSyllabusIncludesYearGroupSyllabus(source=key_stage_syllabus_node, target=year_group_syllabus_node),
            database=db_name, operation='merge'
        )

        if (key_stage, year_group) in year_group_prev_node and year_group_prev_node[(key_stage, year_group)] != year_group_node:
            neon.create_or_merge_neontology_relationship(
                neo_relationships.YearGroupFollowsYearGroup(source=year_group_prev_node[(key_stage, year_group)], target=year_group_node),
                database=db_name, operation='merge'
            )
        year_group_prev_node[(key_stage, year_group)] = year_group_node

# Process topics, lessons, and statements
for index, topic_row in topic_df.iterrows():
    
    yr_syllabus_node = node_library.get(topic_row['SyllabusYearID'])
    if yr_syllabus_node:
        logging.info(f"Processing topic {topic_row['TopicID']} for year group syllabus {topic_row['SyllabusYearID']}")
        topic_node = neo_curriculum.TopicNode(
            topic_id=topic_row['TopicID'],
            topic_title=topic_row.get('TopicTitle', default_topic_values['topic_title']),
            total_number_of_lessons_for_topic=str(topic_row.get('TotalNumberOfLessonsForTopic', default_topic_values['total_number_of_lessons_for_topic'])),
            topic_type=topic_row.get('TopicType', default_topic_values['topic_type']),
            topic_assessment_type=topic_row.get('TopicAssessmentType', default_topic_values['topic_assessment_type'])
        )
        neon.create_or_merge_neontology_node(topic_node, database=db_name, operation='merge')

        neon.create_or_merge_neontology_relationship(
            neo_relationships.TopicPartOfYearGroupSyllabus(source=yr_syllabus_node, target=topic_node),
            database=db_name, operation='merge'
        )

        previous_lesson_node = None
        lessons_df = lesson_df[lesson_df['TopicID'] == topic_row['TopicID']].copy()
        lessons_df.loc[:, 'Lesson'] = lessons_df['Lesson'].astype(str)
        lessons_df = lessons_df.sort_values('Lesson')

        for lesson_index, lesson_row in lessons_df.iterrows():
            lesson_node_data = {
                'topic_lesson_id': lesson_row['LessonID'],
                'topic_lesson_title': lesson_row.get('LessonTitle', default_topic_lesson_values['topic_lesson_title']),
                'topic_lesson_type': lesson_row.get('LessonType', default_topic_lesson_values['topic_lesson_type']),
                'topic_lesson_length': str(lesson_row.get('SuggestedNumberOfPeriodsForLesson', default_topic_lesson_values['topic_lesson_length'])),
                'topic_lesson_suggested_activities': lesson_row.get('SuggestedActivities', default_topic_lesson_values['topic_lesson_suggested_activities']),
                'topic_lesson_skills_learned': lesson_row.get('SkillsLearned', default_topic_lesson_values['topic_lesson_skills_learned']),
                'topic_lesson_weblinks': lesson_row.get('WebLinks', default_topic_lesson_values['topic_lesson_weblinks'])
            }

            # Replace NaN with default values
            for key, value in lesson_node_data.items():
                if pd.isna(value):
                    lesson_node_data[key] = default_topic_lesson_values[key]

            lesson_node = neo_curriculum.TopicLessonNode(**lesson_node_data)
            neon.create_or_merge_neontology_node(lesson_node, database=db_name, operation='merge')

            neon.create_or_merge_neontology_relationship(
                neo_relationships.TopicIncludesTopicLesson(source=topic_node, target=lesson_node),
                database=db_name, operation='merge'
            )

            if previous_lesson_node:
                neon.create_or_merge_neontology_relationship(
                    neo_relationships.TopicLessonFollowsTopicLesson(source=previous_lesson_node, target=lesson_node),
                    database=db_name, operation='merge'
                )
            previous_lesson_node = lesson_node
# Out:
# 2024-06-30 03:45:04,210 INFO      : 1958526637 > <module> >>> Creating key stage node for 3
# 2024-06-30 03:45:04,308 INFO      : 1958526637 > <module> >>> Creating year group node for Year 7
# 2024-06-30 03:45:04,424 INFO      : 1958526637 > <module> >>> Creating year group node for Year 8
# 2024-06-30 03:45:04,481 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:04,483 INFO      : 1958526637 > <module> >>> Creating key stage node for 4
# 2024-06-30 03:45:04,559 INFO      : 1958526637 > <module> >>> Creating year group node for Year 10
# 2024-06-30 03:45:04,731 INFO      : 1958526637 > <module> >>> Creating year group node for Year 11
# 2024-06-30 03:45:04,856 INFO      : 1958526637 > <module> >>> Creating year group node for Year 9
# 2024-06-30 03:45:04,996 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:04,997 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:04,998 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:04,999 INFO      : 1958526637 > <module> >>> Key stage node for 4 already exists
# 2024-06-30 03:45:05,413 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,415 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,415 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,417 INFO      : 1958526637 > <module> >>> Key stage node for 4 already exists
# 2024-06-30 03:45:05,802 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,803 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,804 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:05,804 INFO      : 1958526637 > <module> >>> Creating key stage node for 5
# 2024-06-30 03:45:05,852 INFO      : 1958526637 > <module> >>> Creating year group node for Year 12
# 2024-06-30 03:45:06,002 INFO      : 1958526637 > <module> >>> Creating year group node for Year 13
# 2024-06-30 03:45:06,146 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,147 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,148 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,150 INFO      : 1958526637 > <module> >>> Key stage node for 5 already exists
# 2024-06-30 03:45:06,431 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,433 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,434 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,436 INFO      : 1958526637 > <module> >>> Key stage node for 5 already exists
# 2024-06-30 03:45:06,712 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,714 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,715 WARNING   : 1958526637 > <module> >>> Skipping YearGroup Core as it is not a digit.
# 2024-06-30 03:45:06,717 INFO      : 1958526637 > <module> >>> Processing topic 7B1 for year group syllabus Y7.Science
# 2024-06-30 03:45:07,425 INFO      : 1958526637 > <module> >>> Processing topic 7B2 for year group syllabus Y7.Science
# 2024-06-30 03:45:07,975 INFO      : 1958526637 > <module> >>> Processing topic 7B3 for year group syllabus Y7.Science
# 2024-06-30 03:45:08,514 INFO      : 1958526637 > <module> >>> Processing topic 7B4 for year group syllabus Y7.Science
# 2024-06-30 03:45:09,062 INFO      : 1958526637 > <module> >>> Processing topic 7B5 for year group syllabus Y7.Science
# 2024-06-30 03:45:09,563 INFO      : 1958526637 > <module> >>> Processing topic 7B6 for year group syllabus Y7.Science
# 2024-06-30 03:45:10,115 INFO      : 1958526637 > <module> >>> Processing topic 7C1 for year group syllabus Y7.Science
# 2024-06-30 03:45:10,755 INFO      : 1958526637 > <module> >>> Processing topic 7C2 for year group syllabus Y7.Science
# 2024-06-30 03:45:11,225 INFO      : 1958526637 > <module> >>> Processing topic 7C3 for year group syllabus Y7.Science
# 2024-06-30 03:45:11,765 INFO      : 1958526637 > <module> >>> Processing topic 7C4 for year group syllabus Y7.Science
# 2024-06-30 03:45:12,225 INFO      : 1958526637 > <module> >>> Processing topic 7C5 for year group syllabus Y7.Science
# 2024-06-30 03:45:12,758 INFO      : 1958526637 > <module> >>> Processing topic 7C6 for year group syllabus Y7.Science
# 2024-06-30 03:45:13,347 INFO      : 1958526637 > <module> >>> Processing topic 7P1 for year group syllabus Y7.Science
# 2024-06-30 03:45:14,218 INFO      : 1958526637 > <module> >>> Processing topic 7P2 for year group syllabus Y7.Science
# 2024-06-30 03:45:15,611 INFO      : 1958526637 > <module> >>> Processing topic 7P3 for year group syllabus Y7.Science
# 2024-06-30 03:45:16,822 INFO      : 1958526637 > <module> >>> Processing topic 7P4 for year group syllabus Y7.Science
# 2024-06-30 03:45:17,563 INFO      : 1958526637 > <module> >>> Processing topic 7P5 for year group syllabus Y7.Science
# 2024-06-30 03:45:18,236 INFO      : 1958526637 > <module> >>> Processing topic 7P6 for year group syllabus Y7.Science
# 2024-06-30 03:45:18,680 INFO      : 1958526637 > <module> >>> Processing topic 8B1 for year group syllabus Y8.Science
# 2024-06-30 03:45:19,242 INFO      : 1958526637 > <module> >>> Processing topic 8B2 for year group syllabus Y8.Science
# 2024-06-30 03:45:19,927 INFO      : 1958526637 > <module> >>> Processing topic 8B3 for year group syllabus Y8.Science
# 2024-06-30 03:45:20,581 INFO      : 1958526637 > <module> >>> Processing topic 8B4 for year group syllabus Y8.Science
# 2024-06-30 03:45:21,347 INFO      : 1958526637 > <module> >>> Processing topic 8B5 for year group syllabus Y8.Science
# 2024-06-30 03:45:22,630 INFO      : 1958526637 > <module> >>> Processing topic 8B6 for year group syllabus Y8.Science
# 2024-06-30 03:45:23,573 INFO      : 1958526637 > <module> >>> Processing topic 8C1 for year group syllabus Y8.Science
# 2024-06-30 03:45:24,084 INFO      : 1958526637 > <module> >>> Processing topic 8C2 for year group syllabus Y8.Science
# 2024-06-30 03:45:24,600 INFO      : 1958526637 > <module> >>> Processing topic 8C3 for year group syllabus Y8.Science
# 2024-06-30 03:45:25,261 INFO      : 1958526637 > <module> >>> Processing topic 8C4 for year group syllabus Y8.Science
# 2024-06-30 03:45:25,815 INFO      : 1958526637 > <module> >>> Processing topic 8C5 for year group syllabus Y8.Science
# 2024-06-30 03:45:26,491 INFO      : 1958526637 > <module> >>> Processing topic 8C6 for year group syllabus Y8.Science
# 2024-06-30 03:45:26,866 INFO      : 1958526637 > <module> >>> Processing topic 8P1 for year group syllabus Y8.Science
# 2024-06-30 03:45:27,509 INFO      : 1958526637 > <module> >>> Processing topic 8P2 for year group syllabus Y8.Science
# 2024-06-30 03:45:28,177 INFO      : 1958526637 > <module> >>> Processing topic 8P3 for year group syllabus Y8.Science
# 2024-06-30 03:45:29,217 INFO      : 1958526637 > <module> >>> Processing topic 8P4 for year group syllabus Y8.Science
# 2024-06-30 03:45:30,805 INFO      : 1958526637 > <module> >>> Processing topic 8P5 for year group syllabus Y8.Science
# 2024-06-30 03:45:31,620 INFO      : 1958526637 > <module> >>> Processing topic 8P6 for year group syllabus Y8.Science
# 2024-06-30 03:45:32,186 INFO      : 1958526637 > <module> >>> Processing topic P2 for year group syllabus Y10.Physics
# 2024-06-30 03:45:33,076 INFO      : 1958526637 > <module> >>> Processing topic P3 for year group syllabus Y9.Physics
# 2024-06-30 03:45:33,585 INFO      : 1958526637 > <module> >>> Processing topic P4 for year group syllabus Y9.Physics
# 2024-06-30 03:45:34,159 INFO      : 1958526637 > <module> >>> Processing topic P5 for year group syllabus Y9.Physics
# 2024-06-30 03:45:34,842 INFO      : 1958526637 > <module> >>> Processing topic P6 for year group syllabus Y9.Physics
# 2024-06-30 03:45:35,745 INFO      : 1958526637 > <module> >>> Processing topic P6s for year group syllabus Y11.Physics
# 2024-06-30 03:45:35,784 INFO      : 1958526637 > <module> >>> Processing topic P7 for year group syllabus Y11.Physics
# 2024-06-30 03:45:36,808 INFO      : 1958526637 > <module> >>> Processing topic P8 for year group syllabus Y9.Physics
# 2024-06-30 03:45:36,981 INFO      : 1958526637 > <module> >>> Processing topic P9 for year group syllabus Y11.Physics
# 2024-06-30 03:45:37,923 INFO      : 1958526637 > <module> >>> Processing topic P10 for year group syllabus Y10.Physics
# 2024-06-30 03:45:38,651 INFO      : 1958526637 > <module> >>> Processing topic P11 for year group syllabus Y10.Physics
# 2024-06-30 03:45:39,036 INFO      : 1958526637 > <module> >>> Processing topic P12 for year group syllabus Y10.Physics
# 2024-06-30 03:45:39,384 INFO      : 1958526637 > <module> >>> Processing topic P13 for year group syllabus Y11.Physics
# 2024-06-30 03:45:39,737 INFO      : 1958526637 > <module> >>> Processing topic P14 for year group syllabus Y10.Physics
# 2024-06-30 03:45:40,157 INFO      : 1958526637 > <module> >>> Processing topic P15 for year group syllabus Y11.Physics
# 2024-06-30 03:45:40,627 INFO      : 1958526637 > <module> >>> Processing topic AP.3 for year group syllabus Y12.Physics
# 2024-06-30 03:45:40,875 INFO      : 1958526637 > <module> >>> Processing topic AP.4 for year group syllabus Y12.Physics
# 2024-06-30 03:45:41,116 INFO      : 1958526637 > <module> >>> Processing topic AP.5 for year group syllabus Y12.Physics
# 2024-06-30 03:45:41,363 INFO      : 1958526637 > <module> >>> Processing topic AP.6 for year group syllabus Y12.Physics
# 2024-06-30 03:45:41,603 INFO      : 1958526637 > <module> >>> Processing topic AP.7 for year group syllabus Y12.Physics
# 2024-06-30 03:45:41,814 INFO      : 1958526637 > <module> >>> Processing topic AP.8 for year group syllabus Y12.Physics
# 2024-06-30 03:45:42,219 INFO      : 1958526637 > <module> >>> Processing topic AP.9 for year group syllabus Y12.Physics
# 2024-06-30 03:45:42,849 INFO      : 1958526637 > <module> >>> Processing topic AP.10 for year group syllabus Y12.Physics
# 2024-06-30 03:45:43,389 INFO      : 1958526637 > <module> >>> Processing topic AP.11 for year group syllabus Y12.Physics
# 2024-06-30 03:45:44,952 INFO      : 1958526637 > <module> >>> Processing topic AP.12 for year group syllabus Y12.Physics
# 2024-06-30 03:45:46,060 INFO      : 1958526637 > <module> >>> Processing topic AP.13 for year group syllabus Y12.Physics
# 2024-06-30 03:45:46,476 INFO      : 1958526637 > <module> >>> Processing topic AP.14 for year group syllabus Y13.Physics
# 2024-06-30 03:45:46,704 INFO      : 1958526637 > <module> >>> Processing topic AP.15 for year group syllabus Y13.Physics
# 2024-06-30 03:45:46,964 INFO      : 1958526637 > <module> >>> Processing topic AP.16 for year group syllabus Y13.Physics
# 2024-06-30 03:45:47,228 INFO      : 1958526637 > <module> >>> Processing topic AP.17 for year group syllabus Y13.Physics
# 2024-06-30 03:45:47,477 INFO      : 1958526637 > <module> >>> Processing topic AP.18 for year group syllabus Y13.Physics
# 2024-06-30 03:45:47,732 INFO      : 1958526637 > <module> >>> Processing topic AP.19 for year group syllabus Y13.Physics
# 2024-06-30 03:45:47,963 INFO      : 1958526637 > <module> >>> Processing topic AP.20 for year group syllabus Y13.Physics
# 2024-06-30 03:45:48,217 INFO      : 1958526637 > <module> >>> Processing topic AP.21 for year group syllabus Y13.Physics
# 2024-06-30 03:45:48,437 INFO      : 1958526637 > <module> >>> Processing topic AP.22 for year group syllabus Y13.Physics
# 2024-06-30 03:45:48,683 INFO      : 1958526637 > <module> >>> Processing topic AP.23 for year group syllabus Y13.Physics
# 2024-06-30 03:45:48,922 INFO      : 1958526637 > <module> >>> Processing topic AP.24 for year group syllabus Y13.Physics
# 2024-06-30 03:45:49,179 INFO      : 1958526637 > <module> >>> Processing topic AP.25 for year group syllabus Y13.Physics
# 2024-06-30 03:45:49,419 INFO      : 1958526637 > <module> >>> Processing topic AP.26 for year group syllabus Y13.Physics
# 2024-06-30 03:45:49,665 INFO      : 1958526637 > <module> >>> Processing topic AP.27 for year group syllabus Y13.Physics
